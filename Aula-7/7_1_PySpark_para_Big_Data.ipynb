# %% [markdown]
# # Big Data: Como instalar o PySpark no Google Colab
#
# Como instalar o PySpark no Google Colab é uma dúvida comum entre aqueles que estão migrando seus projetos de Data Science para ambientes na nuvem.
#
# O termo Big Data está cada vez mais presente, e mesmo projetos pessoais podem assumir uma grande dimensionalidade devido à quantidade de dados disponíveis.
#
# Para analisar grandes volumes de dados, Big Data, com velocidade, o Apache Spark é uma ferramenta muito utilizada, dada a sua capacidade de processamento de dados e computação paralela.
#
# O Spark foi pensado para ser acessível, oferecendo diversas APIs e frameworks em Python, Scala, SQL e diversas outras linguagens.
#
# Este tutorial está baseado na documentação oficial, que pode ser conferida [neste link](https://spark.apache.org/docs/latest/api/python/getting_started/index.html).
#
# ## PySpark no Google Colab
#
# [PySpark](https://spark.apache.org/docs/latest/api/python/) é a interface alto nível que permite você conseguir acessar e usar o Spark por meio da linguagem Python. Usando o PySpark, você consegue escrever todo o seu código usando apenas o nosso estilo Python de escrever código.
#
# ## Instalando o PySpark no Google Colab
#
# Instalar o PySpark não é um processo direto como de praxe em Python. Não basta usar um pip install apenas. Na verdade, antes de tudo é necessário instalar dependências como o Java 8, Apache Spark 2.3.2 junto com o Hadoop 2.7.

# %%
# instalar as dependências
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark

# %% [markdown]
# A próxima etapa é configurar as variáveis de ambiente, pois isso habilita o ambiente do Colab a identificar corretamente onde as dependências estão rodando.
#
# Para conseguir “manipular” o terminal e interagir como ele, você pode usar a biblioteca os.

# %%
# configurar as variáveis de ambiente
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# tornar o pyspark "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')

# %% [markdown]
# Feito o processo de instalação das dependências, vamos instalar o `pyspark` e configurar uma sessão:

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 33 kB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 5.5 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=e0740ff57bfd2653b0d89f70bbae6e24470833443fde7ab91e9377dc88b3b8cc
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.3 pyspark-3.2.1

# %% [markdown]
# Com tudo pronto, vamos rodar uma sessão local para testar se a instalação funcionou corretamente.
#
# [SparkSession Explanation](https://towardsdatascience.com/sparksession-vs-sparkcontext-vs-sqlcontext-vs-hivecontext-741d50c9486a)

# %%
# iniciar uma sessão local e importar dados do Airbnb
from pyspark.sql import SparkSession
sc = SparkSession.builder.master('local[*]').getOrCreate()

# download do http para arquivo local
# !wget --quiet --show-progress http://data.insideairbnb.com/brazil/rj/rio-de-janeiro/2021-12-24/visualisations/listings.csv

# carregar dados do Airbnb
df_spark = sc.read.csv("./listings.csv", inferSchema=True, header=True)

# ver algumas informações sobre os tipos de dados de cada coluna
df_spark.printSchema()
# Out:
# listings.csv        100%[===================>]   3.34M  --.-KB/s    in 0.1s
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- host_id: string (nullable = true)
#  |-- host_name: string (nullable = true)
#  |-- neighbourhood_group: string (nullable = true)
#  |-- neighbourhood: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- minimum_nights: string (nullable = true)
#  |-- number_of_reviews: string (nullable = true)
#  |-- last_review: string (nullable = true)
#  |-- reviews_per_month: string (nullable = true)
#  |-- calculated_host_listings_count: string (nullable = true)
#  |-- availability_365: string (nullable = true)
#  |-- number_of_reviews_ltm: double (nullable = true)
#  |-- license: integer (nullable = true)

# %%
import sys
# É como se o dataframe em spark fosse apenas um ponteiro para os dados distribuídos
sys.getsizeof(df_spark)
# Out:
# 64

# %%
import pandas as pd
df_pandas = pd.read_csv("listings.csv")
sys.getsizeof(df_pandas)
# Out:
# 11523735

# %% [markdown]
# A variável `df_spark` é denominado DataFrame PySpark:

# %%
df_spark
# Out:
# DataFrame[id: string, name: string, host_id: string, host_name: string, neighbourhood_group: string, neighbourhood: string, latitude: string, longitude: string, room_type: string, price: string, minimum_nights: string, number_of_reviews: string, last_review: string, reviews_per_month: string, calculated_host_listings_count: string, availability_365: string, number_of_reviews_ltm: double, license: int]

# %% [markdown]
# Para visualizarmos o dataframe, utilizamos o método `.show()`

# %%
df_spark.show()
# Out:
# +-----+--------------------+---------+--------------------+-------------------+---------------+---------+---------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+---------------------+-------+
# |   id|                name|  host_id|           host_name|neighbourhood_group|  neighbourhood| latitude|longitude|      room_type|price|minimum_nights|number_of_reviews|last_review|reviews_per_month|calculated_host_listings_count|availability_365|number_of_reviews_ltm|license|
# +-----+--------------------+---------+--------------------+-------------------+---------------+---------+---------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+---------------------+-------+
# |17878|Very Nice 2Br in ...|    68997|            Matthias|               null|     Copacabana|-22.96599| -43.1794|Entire home/apt|  350|             5|              267| 2021-12-03|             1.92|                             1|             257|                 10.0|   null|
# |24480|Nice and cozy nea...|    99249|                Goya|               null|        Ipanema|-22.98405|-43.20189|Entire home/apt|  296|             3|               85| 2018-02-14|             0.62|                             1|             107|                  0.0|   null|
# |25026|Beautiful Modern ...|   102840|             Viviane|               null|     Copacabana|-22.97735|-43.19105|Entire home/apt|  387|             3|              238| 2020-02-15|             1.69|                             1|             206|                  0.0|   null|
# |35636|Cosy flat close t...|   153232|            Patricia|               null|        Ipanema|-22.98839|-43.19232|Entire home/apt|  172|             2|              181| 2020-03-15|             1.82|                             1|             207|                  0.0|   null|
# |35764|COPACABANA SEA BR...|   153691|Patricia Miranda ...|               null|     Copacabana|-22.98107|-43.19136|Entire home/apt|  260|             3|              378| 2021-12-05|             2.76|                             1|              58|                 32.0|   null|
# |48305|Bright 6bed Penth...|    70933|             Goitaca|               null|        Ipanema|-22.98591|-43.20302|Entire home/apt| 4217|             2|               91| 2021-12-06|             0.69|                             9|             325|                 17.0|   null|
# |48726|Rio de Janeiro Co...|   221941|                Vana|               null|     Copacabana|-22.98528|-43.19264|   Private room|  114|             3|               42| 2019-08-08|             0.83|                             2|              26|                  0.0|   null|
# |48901|Confortable 4BD 3...|   222884|              Marcio|               null|     Copacabana|-22.96574|-43.17514|Entire home/apt| 2015|             2|                8| 2021-12-10|             0.10|                             2|               5|                  4.0|   null|
# |49179|Djalma Ocean View...|   224192|               David|               null|     Copacabana| -22.9791|-43.19008|Entire home/apt|  380|             3|              106| 2021-12-19|             0.96|                            36|             161|                 18.0|   null|
# |50294|Ipanema Beach Blo...|    70933|             Goitaca|               null|        Ipanema|-22.98584|-43.20305|Entire home/apt| 2310|             2|               74| 2021-07-07|             0.58|                             9|             330|                  1.0|   null|
# |50759|Casanova Residenc...|393296342|                Alex|               null|Barra da Tijuca|-23.00451|-43.30873|Entire home/apt| 3050|             1|                7| 2017-01-08|             0.09|                             2|             354|                  0.0|   null|
# |51703|Ocean view, block...|   238091|               Dália|               null|     Copacabana|-22.98234|-43.19164|Entire home/apt|  693|             3|              188| 2021-12-21|             1.65|                             2|             321|                 26.0|   null|
# |53533|4BD JOATINGA-CASA...|   249439|      Sherri & Andre|               null|            Joá|-23.00809|-43.29113|Entire home/apt| 2513|             2|               16| 2021-11-15|             0.13|                             1|             346|                  3.0|   null|
# |64795|Ipanema amazing 3...|    93005|              Andrea|               null|        Ipanema|-22.98169| -43.2028|Entire home/apt| 1157|             3|               28| 2021-11-02|             0.21|                             1|              58|                 16.0|   null|
# |65546|Beach Block 3bed ...|    70933|             Goitaca|               null|        Ipanema|-22.98599|-43.20299|Entire home/apt| 3325|             2|               67| 2021-08-14|             0.51|                             9|             331|                  4.0|   null|
# |66574|Beach apart in Ri...|   326301|            Frederic|               null|       Flamengo|-22.92837|-43.17473|Entire home/apt|  220|             4|                1| 2016-08-24|             0.02|                             1|             321|                  0.0|   null|
# |66797|Studio Apart  for...|   328096|              Carlos|               null|     Copacabana| -22.9824|-43.19593|Entire home/apt|  380|             3|              226| 2021-12-08|             1.72|                             2|             231|                 23.0|   null|
# |68422|Copacabana Beach ...|   339264|               David|               null|     Copacabana|-22.98553|-43.18964|   Private room|  221|             4|               79| 2017-11-22|             0.59|                             1|              77|                  0.0|   null|
# |70080|Apart-hotel in Ip...|   319672|             Valeria|               null|        Ipanema| -22.9854|-43.19602|Entire home/apt|  786|             2|              422| 2021-12-23|             3.48|                             6|             220|                 50.0|   null|
# |72900|IPANEMA-Steps2BEACH!|   379211|                  Lc|               null|        Ipanema|-22.98467|-43.19941|Entire home/apt|  851|             5|               14| 2020-01-05|             0.13|                             1|             210|                  0.0|   null|
# +-----+--------------------+---------+--------------------+-------------------+---------------+---------+---------+---------------+-----+--------------+-----------------+-----------+-----------------+------------------------------+----------------+---------------------+-------+
# only showing top 20 rows

# %% [markdown]
# Alternativamente, você pode habilitar a configuração `spark.sql.repl.eagerEval.enabled` para a avaliação antecipada do PySpark DataFrame em notebooks como Jupyter. O número de linhas a serem exibidas pode ser controlado através da configuração `spark.sql.repl.eagerEval.maxNumRows`.

# %%
sc.conf.set('spark.sql.repl.eagerEval.maxNumRows', 40)

# %%
sc.conf.set('spark.sql.repl.eagerEval.enabled', True)

# %%
df_spark
# Out:
# DataFrame[id: string, name: string, host_id: string, host_name: string, neighbourhood_group: string, neighbourhood: string, latitude: string, longitude: string, room_type: string, price: string, minimum_nights: string, number_of_reviews: string, last_review: string, reviews_per_month: string, calculated_host_listings_count: string, availability_365: string, number_of_reviews_ltm: double, license: int]

# %% [markdown]
# Você pode ver o esquema e os nomes das colunas do DataFrame da seguinte forma:

# %%
df_spark.columns
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license']

# %%
df_spark.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- host_id: string (nullable = true)
#  |-- host_name: string (nullable = true)
#  |-- neighbourhood_group: string (nullable = true)
#  |-- neighbourhood: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- minimum_nights: string (nullable = true)
#  |-- number_of_reviews: string (nullable = true)
#  |-- last_review: string (nullable = true)
#  |-- reviews_per_month: string (nullable = true)
#  |-- calculated_host_listings_count: string (nullable = true)
#  |-- availability_365: string (nullable = true)
#  |-- number_of_reviews_ltm: double (nullable = true)
#  |-- license: integer (nullable = true)

# %% [markdown]
# O resumo do dataframe pode ser representado da seguinte forma:

# %%
df_spark.describe().show()
# Out:
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+-------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------------------+------------------+---------------------+------------------+
# |summary|                  id|                name|             host_id|           host_name| neighbourhood_group|       neighbourhood|           latitude|          longitude|         room_type|             price|    minimum_nights| number_of_reviews|      last_review| reviews_per_month|calculated_host_listings_count|  availability_365|number_of_reviews_ltm|           license|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+-------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------------------+------------------+---------------------+------------------+
# |  count|               24713|               24671|               24549|               24407|                 138|               24541|              24548|              24547|             24549|             24549|             24549|             24491|            15591|             15647|                         24547|             24548|                24421|                11|
# |   mean|2.8718564984439284E7|1.7921067746153846E8|1.1098622615579042E8|         1.5627128E8|         5.0855857E7|  2293595.4459352307|-23.071480446144893|-43.241041185053454|  704.591751238607|1025.4934938254348| 5.378711151621314|14.555528255528255|76.67825000000002|0.7199584425548144|             8.204211276786442|217.72535503320162|    3.654797100855821|31.363636363636363|
# | stddev|   1.7794519959998E7|1.5224276754976022E8| 1.214564613194328E8| 1.553384665946253E8|                 NaN|2.5523490066877503E7|  1.456010623029109|0.37957478864523525|1330.8217092265302| 5404.173519508796|27.547934368278337|34.256712145615126|497.0122377088333|1.2818459124581447|             27.22472064117147|134.32048631073224|     9.28069140888824| 69.17553429829469|
# |    min|  🏖Perto da prai...|                    | 100 meters from ...| 450m from Copaca...| 130m from Metro ...|           -22.75077|          -22.74969|          -22.91152|         -22.98385|          -22.9829|         -43.19335|                 0|                0|              0.01|                             0|                 0|                  0.0|                 0|
# |    max|ótimo para quem v...|🧳 FLAT JARDIM GU...|shopping e muito ...|                一麟|             Vidigal|          Água Santa|        Omar Do Rio|        Shared room|       Shared room|   Entire home/apt|   Entire home/apt|      Private room|             5.22|              9.73|                            93|                99|                348.0|               223|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+-------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------------------+------------------+---------------------+------------------+

# %% [markdown]
# DataFrame.collect() coleta os dados distribuídos para o lado do driver como os dados locais em Python. Observe que isso pode gerar um erro de falta de memória quando o conjunto de dados é muito grande para caber no lado do driver porque ele coleta todos os dados dos executores para o lado do driver.

# %%
df_spark.collect()
# Out:
# [Row(id='17878', name='Very Nice 2Br in Copacabana w. balcony, fast WiFi', host_id='68997', host_name='Matthias', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96599', longitude='-43.1794', room_type='Entire home/apt', price='350', minimum_nights='5', number_of_reviews='267', last_review='2021-12-03', reviews_per_month='1.92', calculated_host_listings_count='1', availability_365='257', number_of_reviews_ltm=10.0, license=None),
#  Row(id='24480', name='Nice and cozy near Ipanema Beach, w/ home office', host_id='99249', host_name='Goya', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98405', longitude='-43.20189', room_type='Entire home/apt', price='296', minimum_nights='3', number_of_reviews='85', last_review='2018-02-14', reviews_per_month='0.62', calculated_host_listings_count='1', availability_365='107', number_of_reviews_ltm=0.0, license=None),
#  Row(id='25026', name='Beautiful Modern Decorated Studio in Copa', host_id='102840', host_name='Viviane', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97735', longitude='-43.19105', room_type='Entire home/apt', price='387', minimum_nights='3', number_of_reviews='238', last_review='2020-02-15', reviews_per_month='1.69', calculated_host_listings_count='1', availability_365='206', number_of_reviews_ltm=0.0, license=None),
#  Row(id='35636', name='Cosy flat close to Ipanema beach', host_id='153232', host_name='Patricia', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98839', longitude='-43.19232', room_type='Entire home/apt', price='172', minimum_nights='2', number_of_reviews='181', last_review='2020-03-15', reviews_per_month='1.82', calculated_host_listings_count='1', availability_365='207', number_of_reviews_ltm=0.0, license=None),
#  Row(id='35764', name='COPACABANA SEA BREEZE  -  RIO - 20 X Superhost', host_id='153691', host_name='Patricia Miranda & Paulo', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98107', longitude='-43.19136', room_type='Entire home/apt', price='260', minimum_nights='3', number_of_reviews='378', last_review='2021-12-05', reviews_per_month='2.76', calculated_host_listings_count='1', availability_365='58', number_of_reviews_ltm=32.0, license=None),
#  Row(id='48305', name='Bright 6bed Penthouse Seconds from Beach', host_id='70933', host_name='Goitaca', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98591', longitude='-43.20302', room_type='Entire home/apt', price='4217', minimum_nights='2', number_of_reviews='91', last_review='2021-12-06', reviews_per_month='0.69', calculated_host_listings_count='9', availability_365='325', number_of_reviews_ltm=17.0, license=None),
#  Row(id='48726', name='Rio de Janeiro Copacabana Ipanema', host_id='221941', host_name='Vana', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98528', longitude='-43.19264', room_type='Private room', price='114', minimum_nights='3', number_of_reviews='42', last_review='2019-08-08', reviews_per_month='0.83', calculated_host_listings_count='2', availability_365='26', number_of_reviews_ltm=0.0, license=None),
#  Row(id='48901', name='Confortable 4BD 3.5BT Atlantic avenue', host_id='222884', host_name='Marcio', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96574', longitude='-43.17514', room_type='Entire home/apt', price='2015', minimum_nights='2', number_of_reviews='8', last_review='2021-12-10', reviews_per_month='0.10', calculated_host_listings_count='2', availability_365='5', number_of_reviews_ltm=4.0, license=None),
#  Row(id='49179', name='Djalma Ocean View Studio with Amazing Views #100A', host_id='224192', host_name='David', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.9791', longitude='-43.19008', room_type='Entire home/apt', price='380', minimum_nights='3', number_of_reviews='106', last_review='2021-12-19', reviews_per_month='0.96', calculated_host_listings_count='36', availability_365='161', number_of_reviews_ltm=18.0, license=None),
#  Row(id='50294', name='Ipanema Beach Block Suites Just Seconds from the Beach', host_id='70933', host_name='Goitaca', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98584', longitude='-43.20305', room_type='Entire home/apt', price='2310', minimum_nights='2', number_of_reviews='74', last_review='2021-07-07', reviews_per_month='0.58', calculated_host_listings_count='9', availability_365='330', number_of_reviews_ltm=1.0, license=None),
#  Row(id='50759', name='Casanova Residence great for shoots and events', host_id='393296342', host_name='Alex', neighbourhood_group=None, neighbourhood='Barra da Tijuca', latitude='-23.00451', longitude='-43.30873', room_type='Entire home/apt', price='3050', minimum_nights='1', number_of_reviews='7', last_review='2017-01-08', reviews_per_month='0.09', calculated_host_listings_count='2', availability_365='354', number_of_reviews_ltm=0.0, license=None),
#  Row(id='51703', name='Ocean view, block of the beach, Copacabana,Ipanema', host_id='238091', host_name='Dália', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98234', longitude='-43.19164', room_type='Entire home/apt', price='693', minimum_nights='3', number_of_reviews='188', last_review='2021-12-21', reviews_per_month='1.65', calculated_host_listings_count='2', availability_365='321', number_of_reviews_ltm=26.0, license=None),
#  Row(id='53533', name='4BD JOATINGA-CASA LINDA w/POOL!  WALK TO BEACH🌺🌺🌺', host_id='249439', host_name='Sherri & Andre', neighbourhood_group=None, neighbourhood='Joá', latitude='-23.00809', longitude='-43.29113', room_type='Entire home/apt', price='2513', minimum_nights='2', number_of_reviews='16', last_review='2021-11-15', reviews_per_month='0.13', calculated_host_listings_count='1', availability_365='346', number_of_reviews_ltm=3.0, license=None),
#  Row(id='64795', name='Ipanema amazing 3 BDRs apartment.', host_id='93005', host_name='Andrea', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98169', longitude='-43.2028', room_type='Entire home/apt', price='1157', minimum_nights='3', number_of_reviews='28', last_review='2021-11-02', reviews_per_month='0.21', calculated_host_listings_count='1', availability_365='58', number_of_reviews_ltm=16.0, license=None),
#  Row(id='65546', name='Beach Block 3bed Penthouse, Ipanema Best Location', host_id='70933', host_name='Goitaca', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98599', longitude='-43.20299', room_type='Entire home/apt', price='3325', minimum_nights='2', number_of_reviews='67', last_review='2021-08-14', reviews_per_month='0.51', calculated_host_listings_count='9', availability_365='331', number_of_reviews_ltm=4.0, license=None),
#  Row(id='66574', name='Beach apart in Rio (jan. 2022)', host_id='326301', host_name='Frederic', neighbourhood_group=None, neighbourhood='Flamengo', latitude='-22.92837', longitude='-43.17473', room_type='Entire home/apt', price='220', minimum_nights='4', number_of_reviews='1', last_review='2016-08-24', reviews_per_month='0.02', calculated_host_listings_count='1', availability_365='321', number_of_reviews_ltm=0.0, license=None),
#  Row(id='66797', name='Studio Apart  for rent in ipanema.', host_id='328096', host_name='Carlos', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.9824', longitude='-43.19593', room_type='Entire home/apt', price='380', minimum_nights='3', number_of_reviews='226', last_review='2021-12-08', reviews_per_month='1.72', calculated_host_listings_count='2', availability_365='231', number_of_reviews_ltm=23.0, license=None),
#  Row(id='68422', name='Copacabana Beach Living+AirConWiFi', host_id='339264', host_name='David', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98553', longitude='-43.18964', room_type='Private room', price='221', minimum_nights='4', number_of_reviews='79', last_review='2017-11-22', reviews_per_month='0.59', calculated_host_listings_count='1', availability_365='77', number_of_reviews_ltm=0.0, license=None),
#  Row(id='70080', name='Apart-hotel in Ipanema with service and garage', host_id='319672', host_name='Valeria', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.9854', longitude='-43.19602', room_type='Entire home/apt', price='786', minimum_nights='2', number_of_reviews='422', last_review='2021-12-23', reviews_per_month='3.48', calculated_host_listings_count='6', availability_365='220', number_of_reviews_ltm=50.0, license=None),
#  Row(id='72900', name='IPANEMA-Steps2BEACH!', host_id='379211', host_name='Lc', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98467', longitude='-43.19941', room_type='Entire home/apt', price='851', minimum_nights='5', number_of_reviews='14', last_review='2020-01-05', reviews_per_month='0.13', calculated_host_listings_count='1', availability_365='210', number_of_reviews_ltm=0.0, license=None),
#  Row(id='76245', name='Spacious Home Heart of Rio290m4QT. Discount10%week', host_id='406651', host_name='Diogo', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98192', longitude='-43.19397', room_type='Entire home/apt', price='3149', minimum_nights='2', number_of_reviews='127', last_review='2021-11-15', reviews_per_month='1.00', calculated_host_listings_count='1', availability_365='221', number_of_reviews_ltm=2.0, license=None),
#  Row(id='76300', name='"GREAT VIEW -Guesthouse ""CASA 48""- Santa Teresa  #1"', host_id='406989', host_name='Casa 48 Guesthouse', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.92742', longitude='-43.19464', room_type='Private room', price='225', minimum_nights='7', number_of_reviews='215', last_review='2021-03-16', reviews_per_month='1.79', calculated_host_listings_count='6', availability_365='269', number_of_reviews_ltm=2.0, license=None),
#  Row(id='77318', name='❤Unique RIO | retreat w/ forest view in hot spot', host_id='110002', host_name='Silvia', neighbourhood_group=None, neighbourhood='Gávea', latitude='-22.97766', longitude='-43.2311', room_type='Entire home/apt', price='373', minimum_nights='5', number_of_reviews='37', last_review='2021-04-30', reviews_per_month='0.34', calculated_host_listings_count='1', availability_365='0', number_of_reviews_ltm=2.0, license=None),
#  Row(id='80145', name='Stay in a small imperial castle !', host_id='432777', host_name='Andreas', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.92456', longitude='-43.19028', room_type='Private room', price='243', minimum_nights='2', number_of_reviews='14', last_review='2019-10-06', reviews_per_month='0.13', calculated_host_listings_count='2', availability_365='360', number_of_reviews_ltm=0.0, license=None),
#  Row(id='86670', name='FRONTEIRA LEBLON/IPANEMA - VISTA FANTÁSTICA', host_id='474221', host_name='June', neighbourhood_group=None, neighbourhood='Leblon', latitude='-22.98361', longitude='-43.21827', room_type='Entire home/apt', price='690', minimum_nights='2', number_of_reviews='92', last_review='2021-12-11', reviews_per_month='0.73', calculated_host_listings_count='6', availability_365='34', number_of_reviews_ltm=11.0, license=None),
#  Row(id='86864', name='Apartamento Moderno e confortavel', host_id='476162', host_name='Simone', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98174', longitude='-43.19039', room_type='Entire home/apt', price='500', minimum_nights='5', number_of_reviews='7', last_review='2021-12-14', reviews_per_month='1.54', calculated_host_listings_count='4', availability_365='288', number_of_reviews_ltm=7.0, license=None),
#  Row(id='86978', name='Room For a Rent : Rio de Janeiro', host_id='476838', host_name='Antonio', neighbourhood_group=None, neighbourhood='Jacarepaguá', latitude='-22.97293', longitude='-43.38321', room_type='Private room', price='851', minimum_nights='1', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='87762', name='Apartamento a 1 quadra da praia de Ipanema/Leblon', host_id='480527', host_name='Pablo', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98339', longitude='-43.21436', room_type='Entire home/apt', price='293', minimum_nights='2', number_of_reviews='32', last_review='2021-11-29', reviews_per_month='0.61', calculated_host_listings_count='1', availability_365='45', number_of_reviews_ltm=17.0, license=None),
#  Row(id='88528', name='COPACABANA - Lindo apartamento na quadra da praia', host_id='474221', host_name='June', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97794', longitude='-43.18969', room_type='Entire home/apt', price='460', minimum_nights='2', number_of_reviews='71', last_review='2021-12-02', reviews_per_month='0.57', calculated_host_listings_count='6', availability_365='279', number_of_reviews_ltm=6.0, license=None),
#  Row(id='88781', name='COPACABANA - ÓTIMA LOCALIZAÇÃO', host_id='474221', host_name='June', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97456', longitude='-43.18807', room_type='Entire home/apt', price='460', minimum_nights='2', number_of_reviews='62', last_review='2021-11-30', reviews_per_month='0.57', calculated_host_listings_count='6', availability_365='222', number_of_reviews_ltm=15.0, license=None),
#  Row(id='89862', name='COPACABANA - No melhor lugar', host_id='474221', host_name='June', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97607', longitude='-43.18926', room_type='Entire home/apt', price='448', minimum_nights='2', number_of_reviews='47', last_review='2021-11-29', reviews_per_month='0.43', calculated_host_listings_count='6', availability_365='175', number_of_reviews_ltm=2.0, license=None),
#  Row(id='89893', name='Exotic place in Rio de Janeiro.', host_id='483023', host_name='Geny', neighbourhood_group=None, neighbourhood='Laranjeiras', latitude='-22.94124', longitude='-43.19214', room_type='Private room', price='511', minimum_nights='1', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='89981', name='IPANEMA  QUARTO + BANHEIRO PRIVADO', host_id='488707', host_name='Celia', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98088', longitude='-43.20042', room_type='Private room', price='227', minimum_nights='3', number_of_reviews='167', last_review='2020-02-27', reviews_per_month='1.38', calculated_host_listings_count='1', availability_365='240', number_of_reviews_ltm=0.0, license=None),
#  Row(id='94895', name='Quarto em Copacabana - temporada', host_id='506187', host_name='Sheila', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97256', longitude='-43.18948', room_type='Private room', price='163', minimum_nights='1', number_of_reviews='7', last_review='2020-02-25', reviews_per_month='0.10', calculated_host_listings_count='3', availability_365='326', number_of_reviews_ltm=0.0, license=None),
#  Row(id='96431', name='Amazing ocean view !', host_id='511850', host_name='Marina E Ernani', neighbourhood_group=None, neighbourhood='Barra da Tijuca', latitude='-23.01124', longitude='-43.37081', room_type='Entire home/apt', price='523', minimum_nights='4', number_of_reviews='51', last_review='2021-04-05', reviews_per_month='0.48', calculated_host_listings_count='2', availability_365='280', number_of_reviews_ltm=2.0, license=None),
#  Row(id='96478', name='APARTAMENT IN BOTAFOGO  BEAUTIFULL', host_id='530471', host_name='Hugo', neighbourhood_group=None, neighbourhood='Botafogo', latitude='-22.94656', longitude='-43.18176', room_type='Private room', price='170', minimum_nights='4', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='3', availability_365='334', number_of_reviews_ltm=0.0, license=None),
#  Row(id='97636', name='Rio de Janeiro for you! Go for it!', host_id='496656', host_name='Marcia  Longras', neighbourhood_group=None, neighbourhood='Botafogo', latitude='-22.94169', longitude='-43.18703', room_type='Private room', price='192', minimum_nights='8', number_of_reviews='17', last_review='2019-10-07', reviews_per_month='0.14', calculated_host_listings_count='7', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='99547', name='Lapa Archs | Santa Teresa best studio for 2 people', host_id='524101', host_name='Fabiana', neighbourhood_group=None, neighbourhood='Centro', latitude='-22.91408', longitude='-43.18233', room_type='Entire home/apt', price='190', minimum_nights='4', number_of_reviews='61', last_review='2021-03-11', reviews_per_month='0.57', calculated_host_listings_count='2', availability_365='162', number_of_reviews_ltm=1.0, license=None),
#  Row(id='99971', name='Right in front of the beach in Rio!', host_id='525976', host_name='Ricardo', neighbourhood_group=None, neighbourhood='Leblon', latitude='-22.98812', longitude='-43.22897', room_type='Entire home/apt', price='1065', minimum_nights='3', number_of_reviews='112', last_review='2021-12-20', reviews_per_month='0.89', calculated_host_listings_count='1', availability_365='307', number_of_reviews_ltm=5.0, license=None),
#  Row(id='101182', name='APARTAMENT IN FRONT OF THE BEACH', host_id='530471', host_name='Hugo', neighbourhood_group=None, neighbourhood='Botafogo', latitude='-22.94837', longitude='-43.18315', room_type='Entire home/apt', price='200', minimum_nights='4', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='3', availability_365='350', number_of_reviews_ltm=0.0, license=None),
#  Row(id='103053', name='santa teresa bairro fatima lapa', host_id='533278', host_name='Kaka', neighbourhood_group=None, neighbourhood='Santo Cristo', latitude='-22.90559', longitude='-43.20979', room_type='Private room', price='397', minimum_nights='1', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='106372', name='Reveillon & Natal na Barra da Tijuca. Rj', host_id='551316', host_name='Katia', neighbourhood_group=None, neighbourhood='Barra da Tijuca', latitude='-23.00744', longitude='-43.43045', room_type='Entire home/apt', price='800', minimum_nights='4', number_of_reviews='7', last_review='2020-02-26', reviews_per_month='0.11', calculated_host_listings_count='1', availability_365='357', number_of_reviews_ltm=0.0, license=None),
#  Row(id='107469', name='Quarto confortável com vista panorâmica', host_id='556738', host_name='Casa Da Carmen E', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.91889', longitude='-43.18038', room_type='Private room', price='60', minimum_nights='60', number_of_reviews='2', last_review='2018-12-21', reviews_per_month='0.02', calculated_host_listings_count='4', availability_365='360', number_of_reviews_ltm=0.0, license=None),
#  Row(id='108072', name='Nice 1 BR Apartment in Copacabana', host_id='521514', host_name='Chris', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98314', longitude='-43.19086', room_type='Entire home/apt', price='320', minimum_nights='4', number_of_reviews='150', last_review='2021-10-12', reviews_per_month='1.16', calculated_host_listings_count='1', availability_365='346', number_of_reviews_ltm=6.0, license=None),
#  Row(id='108882', name='Gloria Sunshine Apartment in Rio', host_id='475926', host_name='Angelica/ Fca', neighbourhood_group=None, neighbourhood='Glória', latitude='-22.91972', longitude='-43.1789', room_type='Entire home/apt', price='496', minimum_nights='3', number_of_reviews='58', last_review='2021-09-13', reviews_per_month='0.45', calculated_host_listings_count='1', availability_365='61', number_of_reviews_ltm=1.0, license=None),
#  Row(id='109747', name="IPANEMA'S MOST BEAUTIFUL VIEW for 6+2", host_id='554897', host_name='Jane', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98697', longitude='-43.19751', room_type='Entire home/apt', price='1338', minimum_nights='2', number_of_reviews='169', last_review='2021-12-22', reviews_per_month='1.39', calculated_host_listings_count='1', availability_365='279', number_of_reviews_ltm=19.0, license=None),
#  Row(id='118355', name='HOUSE IN GARDEN', host_id='523251', host_name='Humberto', neighbourhood_group=None, neighbourhood='Itanhangá', latitude='-22.98752', longitude='-43.31505', room_type='Entire home/apt', price='3679', minimum_nights='1', number_of_reviews='7', last_review='2021-12-12', reviews_per_month='0.19', calculated_host_listings_count='6', availability_365='244', number_of_reviews_ltm=5.0, license=None),
#  Row(id='125656', name='Copacabana Studio -  5* Reviews, 5 mins to Beach', host_id='624433', host_name='Alan & Catherine', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.9696', longitude='-43.1887', room_type='Entire home/apt', price='797', minimum_nights='3', number_of_reviews='85', last_review='2020-02-27', reviews_per_month='0.66', calculated_host_listings_count='1', availability_365='279', number_of_reviews_ltm=0.0, license=None),
#  Row(id='128727', name='Double room in family house', host_id='622729', host_name='Geraldo & Shalluan', neighbourhood_group=None, neighbourhood='Praça Seca', latitude='-22.895765', longitude='-43.353809', room_type='Private room', price='250', minimum_nights='1', number_of_reviews='4', last_review='2017-03-26', reviews_per_month='0.03', calculated_host_listings_count='1', availability_365='0', number_of_reviews_ltm=0.0, license=None),
#  Row(id='130234', name='excellent studio apartment', host_id='641519', host_name='Osvaldo', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97575', longitude='-43.18877', room_type='Entire home/apt', price='180', minimum_nights='3', number_of_reviews='4', last_review='2019-02-16', reviews_per_month='0.09', calculated_host_listings_count='1', availability_365='0', number_of_reviews_ltm=0.0, license=None),
#  Row(id='132114', name='beauty beedrom in Laranjeiras.', host_id='649320', host_name='Stella E Antonio', neighbourhood_group=None, neighbourhood='Laranjeiras', latitude='-22.93707', longitude='-43.19071', room_type='Private room', price='105', minimum_nights='1', number_of_reviews='5', last_review='2018-06-05', reviews_per_month='0.05', calculated_host_listings_count='1', availability_365='359', number_of_reviews_ltm=0.0, license=None),
#  Row(id='132832', name='VISTA PRAIA COPA - Excelente Quarto', host_id='652627', host_name='Ana', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98282', longitude='-43.18935', room_type='Private room', price='160', minimum_nights='2', number_of_reviews='4', last_review='2019-01-04', reviews_per_month='0.05', calculated_host_listings_count='5', availability_365='18', number_of_reviews_ltm=0.0, license=None),
#  Row(id='132909', name='QUARTO PRIVATIVO', host_id='652889', host_name='Fernando Patricio', neighbourhood_group=None, neighbourhood='Maracanã', latitude='-22.91547', longitude='-43.22638', room_type='Private room', price='300', minimum_nights='1', number_of_reviews='1', last_review='2016-02-02', reviews_per_month='0.01', calculated_host_listings_count='1', availability_365='364', number_of_reviews_ltm=0.0, license=None),
#  Row(id='133221', name='The room has its own toilet.', host_id='6416134', host_name='Rosangela', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.91882', longitude='-43.17828', room_type='Private room', price='70', minimum_nights='2', number_of_reviews='30', last_review='2020-02-29', reviews_per_month='0.29', calculated_host_listings_count='1', availability_365='356', number_of_reviews_ltm=0.0, license=None),
#  Row(id='137002', name='Very sophisticated in the mettle of Leblon, av. Cupertino', host_id='635510', host_name='Gilberto', neighbourhood_group=None, neighbourhood='Leblon', latitude='-22.98251', longitude='-43.22108', room_type='Entire home/apt', price='2703', minimum_nights='2', number_of_reviews='26', last_review='2021-11-15', reviews_per_month='0.21', calculated_host_listings_count='5', availability_365='307', number_of_reviews_ltm=10.0, license=None),
#  Row(id='137048', name='Charming 2 bedroom flat in Leblon', host_id='670198', host_name='Clarisse', neighbourhood_group=None, neighbourhood='Leblon', latitude='-22.98175', longitude='-43.22492', room_type='Entire home/apt', price='393', minimum_nights='3', number_of_reviews='35', last_review='2021-05-14', reviews_per_month='0.28', calculated_host_listings_count='1', availability_365='154', number_of_reviews_ltm=2.0, license=None),
#  Row(id='137150', name='Penthouse at Lagoa close to Ipanema', host_id='670788', host_name='Roberto', neighbourhood_group=None, neighbourhood='Lagoa', latitude='-22.97366', longitude='-43.20493', room_type='Entire home/apt', price='2838', minimum_nights='21', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='137343', name='2BR, 2 blocks from Ipanema Beach', host_id='671579', host_name='Karen', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98456', longitude='-43.1956', room_type='Entire home/apt', price='397', minimum_nights='6', number_of_reviews='39', last_review='2020-05-15', reviews_per_month='0.31', calculated_host_listings_count='1', availability_365='299', number_of_reviews_ltm=0.0, license=None),
#  Row(id='141434', name='URCA Amazing Penthouse w/ best view/ 230 m2', host_id='687759', host_name='Adriana', neighbourhood_group=None, neighbourhood='Botafogo', latitude='-22.95454', longitude='-43.17442', room_type='Entire home/apt', price='1127', minimum_nights='2', number_of_reviews='35', last_review='2021-11-30', reviews_per_month='0.27', calculated_host_listings_count='2', availability_365='320', number_of_reviews_ltm=10.0, license=None),
#  Row(id='146402', name='Suite in a beautiful house-Lagoa/RJ', host_id='713797', host_name='Rosalia', neighbourhood_group=None, neighbourhood='Humaitá', latitude='-22.96148', longitude='-43.20038', room_type='Private room', price='486', minimum_nights='2', number_of_reviews='81', last_review='2020-09-13', reviews_per_month='0.69', calculated_host_listings_count='2', availability_365='351', number_of_reviews_ltm=0.0, license=None),
#  Row(id='154127', name='Lindo Apt. Rio Centro / Rock in Rio', host_id='757937', host_name='Renata', neighbourhood_group=None, neighbourhood='Jacarepaguá', latitude='-22.97275', longitude='-43.41337', room_type='Entire home/apt', price='500', minimum_nights='1', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='361', number_of_reviews_ltm=0.0, license=None),
#  Row(id='166177', name='Studio  70 meters from Copacabana beach', host_id='792218', host_name='Levy', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97854', longitude='-43.1904', room_type='Entire home/apt', price='367', minimum_nights='2', number_of_reviews='92', last_review='2021-12-13', reviews_per_month='0.73', calculated_host_listings_count='10', availability_365='326', number_of_reviews_ltm=7.0, license=None),
#  Row(id='166861', name='Private Double room at Copacabana', host_id='454863', host_name='Dary', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98413', longitude='-43.19235', room_type='Private room', price='234', minimum_nights='3', number_of_reviews='12', last_review='2020-02-27', reviews_per_month='0.13', calculated_host_listings_count='2', availability_365='323', number_of_reviews_ltm=0.0, license=None),
#  Row(id='166972', name='O MELHOR ESTÚDIO DE  COPACABANA', host_id='795470', host_name='Luiz Otavio', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96614', longitude='-43.18401', room_type='Entire home/apt', price='299', minimum_nights='3', number_of_reviews='1', last_review='2019-11-06', reviews_per_month='0.04', calculated_host_listings_count='1', availability_365='238', number_of_reviews_ltm=0.0, license=None),
#  Row(id='167031', name='Arpoador beach, the best part of Ipanema', host_id='792218', host_name='Levy', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.9869', longitude='-43.19286', room_type='Entire home/apt', price='523', minimum_nights='2', number_of_reviews='64', last_review='2021-12-17', reviews_per_month='0.57', calculated_host_listings_count='10', availability_365='310', number_of_reviews_ltm=6.0, license=None),
#  Row(id='167932', name='Quiet studio in the best of COPA', host_id='792218', host_name='Levy', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97064', longitude='-43.18496', room_type='Entire home/apt', price='410', minimum_nights='2', number_of_reviews='77', last_review='2021-11-03', reviews_per_month='0.62', calculated_host_listings_count='10', availability_365='293', number_of_reviews_ltm=4.0, license=None),
#  Row(id='170265', name='Quarto confortável na praia da Barra da Tijuca', host_id='811735', host_name='Ivana', neighbourhood_group=None, neighbourhood='Barra da Tijuca', latitude='-23.0102', longitude='-43.37246', room_type='Private room', price='264', minimum_nights='2', number_of_reviews='1', last_review='2019-10-06', reviews_per_month='0.04', calculated_host_listings_count='2', availability_365='363', number_of_reviews_ltm=0.0, license=None),
#  Row(id='170397', name='Studio in the HEART of Copacabana', host_id='792218', host_name='Levy', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97135', longitude='-43.18779', room_type='Entire home/apt', price='381', minimum_nights='2', number_of_reviews='102', last_review='2021-12-01', reviews_per_month='0.82', calculated_host_listings_count='10', availability_365='303', number_of_reviews_ltm=3.0, license=None),
#  Row(id='171505', name='Come and feel at home', host_id='820276', host_name='Cristiana', neighbourhood_group=None, neighbourhood='Vidigal', latitude='-22.99327', longitude='-43.23481', room_type='Entire home/apt', price='454', minimum_nights='3', number_of_reviews='1', last_review='2016-08-21', reviews_per_month='0.02', calculated_host_listings_count='1', availability_365='363', number_of_reviews_ltm=0.0, license=None),
#  Row(id='172902', name='Studio between Ipanema / Copacabana', host_id='792218', host_name='Levy', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98114', longitude='-43.19429', room_type='Entire home/apt', price='329', minimum_nights='2', number_of_reviews='96', last_review='2021-12-12', reviews_per_month='0.76', calculated_host_listings_count='10', availability_365='326', number_of_reviews_ltm=10.0, license=None),
#  Row(id='173709', name='Excelent apt near Copacabana beach', host_id='829630', host_name='Luciana', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96104', longitude='-43.17647', room_type='Entire home/apt', price='510', minimum_nights='1', number_of_reviews='78', last_review='2021-12-02', reviews_per_month='0.64', calculated_host_listings_count='3', availability_365='71', number_of_reviews_ltm=15.0, license=None),
#  Row(id='174101', name='Penthouse & Private Airy and Quiet Terrace', host_id='259815', host_name='Valerie & Alex', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98015', longitude='-43.19098', room_type='Entire home/apt', price='903', minimum_nights='3', number_of_reviews='196', last_review='2021-12-13', reviews_per_month='1.56', calculated_host_listings_count='2', availability_365='44', number_of_reviews_ltm=6.0, license=None),
#  Row(id='176185', name='Penthouse Oceanview Copacab/Ipanema', host_id='842466', host_name='Wolfgang', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98401', longitude='-43.19035', room_type='Entire home/apt', price='3489', minimum_nights='3', number_of_reviews='144', last_review='2021-11-29', reviews_per_month='1.16', calculated_host_listings_count='1', availability_365='358', number_of_reviews_ltm=4.0, license=None),
#  Row(id='178833', name='Penthouse #1! Best Internet! Veranda! Expat US-DE', host_id='856145', host_name='Mario', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98026', longitude='-43.19109', room_type='Private room', price='330', minimum_nights='5', number_of_reviews='110', last_review='2021-12-11', reviews_per_month='0.87', calculated_host_listings_count='3', availability_365='289', number_of_reviews_ltm=5.0, license=None),
#  Row(id='178951', name='Penthouse #2! Best Internet! Veranda! Expat US-DE', host_id='856145', host_name='Mario', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97858', longitude='-43.19075', room_type='Entire home/apt', price='329', minimum_nights='10', number_of_reviews='89', last_review='2021-11-26', reviews_per_month='0.70', calculated_host_listings_count='3', availability_365='315', number_of_reviews_ltm=9.0, license=None),
#  Row(id='181138', name='Stunning penthouse with ocean view and panoramic terrace, beach one minute away.', host_id='868175', host_name='Yann', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98467', longitude='-43.19166', room_type='Entire home/apt', price='1611', minimum_nights='3', number_of_reviews='68', last_review='2021-11-02', reviews_per_month='0.55', calculated_host_listings_count='1', availability_365='251', number_of_reviews_ltm=5.0, license=None),
#  Row(id='186604', name='Private room in downtown Rio', host_id='896919', host_name='Mauro', neighbourhood_group=None, neighbourhood='Centro', latitude='-22.90544', longitude='-43.19471', room_type='Private room', price='681', minimum_nights='3', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='188155', name='Copacabana - 2 rooms - Carnival available', host_id='617333', host_name='Luis', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96775', longitude='-43.18457', room_type='Entire home/apt', price='657', minimum_nights='2', number_of_reviews='42', last_review='2021-11-15', reviews_per_month='0.34', calculated_host_listings_count='3', availability_365='176', number_of_reviews_ltm=10.0, license=None),
#  Row(id='190204', name='Venusian Room at Botafogo', host_id='918340', host_name='Flávia', neighbourhood_group=None, neighbourhood='Botafogo', latitude='-22.94882', longitude='-43.18121', room_type='Private room', price='800', minimum_nights='3', number_of_reviews='46', last_review='2020-03-24', reviews_per_month='0.40', calculated_host_listings_count='2', availability_365='359', number_of_reviews_ltm=0.0, license=None),
#  Row(id='190906', name='Charmoso apartamento na praia de Ipanema', host_id='823800', host_name='Rafaella', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98057', longitude='-43.1995', room_type='Entire home/apt', price='626', minimum_nights='4', number_of_reviews='167', last_review='2021-11-14', reviews_per_month='1.33', calculated_host_listings_count='27', availability_365='204', number_of_reviews_ltm=8.0, license=None),
#  Row(id='191955', name='bedroom suite', host_id='929229', host_name='Arlete', neighbourhood_group=None, neighbourhood='Humaitá', latitude='-22.95644', longitude='-43.19992', room_type='Private room', price='164', minimum_nights='5', number_of_reviews='1', last_review='2016-01-18', reviews_per_month='0.01', calculated_host_listings_count='2', availability_365='359', number_of_reviews_ltm=0.0, license=None),
#  Row(id='193317', name='Bedroom Ipanema 1 block from beach', host_id='937397', host_name='Adriano', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98467', longitude='-43.19714', room_type='Private room', price='442', minimum_nights='4', number_of_reviews='183', last_review='2021-11-27', reviews_per_month='1.67', calculated_host_listings_count='3', availability_365='133', number_of_reviews_ltm=2.0, license=None),
#  Row(id='196312', name='Flat between Copacabana & Ipanema', host_id='955720', host_name='Priscilla', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98357', longitude='-43.19408', room_type='Entire home/apt', price='180', minimum_nights='2', number_of_reviews='76', last_review='2020-01-05', reviews_per_month='0.61', calculated_host_listings_count='1', availability_365='83', number_of_reviews_ltm=0.0, license=None),
#  Row(id='198646', name='COME SPEND THE BEST PLACE IN RIO!!!', host_id='969822', host_name='Lucia', neighbourhood_group=None, neighbourhood='Marechal Hermes', latitude='-22.8607', longitude='-43.36681', room_type='Private room', price='69', minimum_nights='1', number_of_reviews='6', last_review='2017-11-26', reviews_per_month='0.05', calculated_host_listings_count='2', availability_365='363', number_of_reviews_ltm=0.0, license=None),
#  Row(id='198665', name='Comfort and safety on your trip', host_id='969899', host_name='Josevalda', neighbourhood_group=None, neighbourhood='Jardim Botânico', latitude='-22.96055', longitude='-43.22285', room_type='Private room', price='511', minimum_nights='3', number_of_reviews='6', last_review='2016-08-16', reviews_per_month='0.05', calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='200568', name='30m of Ipa Beach - S1  Mensal', host_id='980805', host_name='Henrique', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98586', longitude='-43.19411', room_type='Entire home/apt', price='80', minimum_nights='7', number_of_reviews='186', last_review='2021-10-30', reviews_per_month='1.53', calculated_host_listings_count='7', availability_365='32', number_of_reviews_ltm=2.0, license=None),
#  Row(id='201308', name='Nice area,  safe,clean and central', host_id='984392', host_name='Mrs. Cindy', neighbourhood_group=None, neighbourhood='Laranjeiras', latitude='-22.93595', longitude='-43.18791', room_type='Private room', price='851', minimum_nights='3', number_of_reviews='2', last_review='2016-02-12', reviews_per_month='0.02', calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='202400', name='COPACABANA - RIO DE JANEIRO - 1/2 block from beach', host_id='961863', host_name='Caesar', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97323', longitude='-43.18819', room_type='Entire home/apt', price='369', minimum_nights='3', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='268', number_of_reviews_ltm=0.0, license=None),
#  Row(id='202778', name='Best Studio in Rio - Copacabana', host_id='529105', host_name='Alex', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96582', longitude='-43.17786', room_type='Entire home/apt', price='840', minimum_nights='3', number_of_reviews='204', last_review='2021-11-02', reviews_per_month='1.63', calculated_host_listings_count='3', availability_365='349', number_of_reviews_ltm=4.0, license=None),
#  Row(id='203674', name='IPANEMA PENTHOUSE,JACUZZI + STUNNING CRISTO VIEWS!', host_id='999125', host_name='Alastair', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98335', longitude='-43.20306', room_type='Entire home/apt', price='2255', minimum_nights='5', number_of_reviews='48', last_review='2019-05-07', reviews_per_month='0.41', calculated_host_listings_count='1', availability_365='255', number_of_reviews_ltm=0.0, license=None),
#  Row(id='209671', name='1 bed apartment in beautiful Gloria', host_id='1005728', host_name='Humphry', neighbourhood_group=None, neighbourhood='Glória', latitude='-22.92368', longitude='-43.17421', room_type='Entire home/apt', price='224', minimum_nights='7', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='156', number_of_reviews_ltm=0.0, license=None),
#  Row(id='210173', name='BEAUTIFUL! Spacious,all rooms', host_id='1030316', host_name='Elizabeth', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98596', longitude='-43.19001', room_type='Private room', price='1576', minimum_nights='2', number_of_reviews='3', last_review='2019-10-03', reviews_per_month='0.02', calculated_host_listings_count='4', availability_365='320', number_of_reviews_ltm=0.0, license=None),
#  Row(id='215793', name='BEAUTIFUL! Spacious,king room!', host_id='1030316', host_name='Elizabeth', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98596', longitude='-43.19001', room_type='Private room', price='500', minimum_nights='2', number_of_reviews='31', last_review='2021-11-17', reviews_per_month='0.25', calculated_host_listings_count='4', availability_365='351', number_of_reviews_ltm=2.0, license=None),
#  Row(id='215878', name='Beautiful! Spacious ,Queen Room !!!', host_id='1030316', host_name='Elizabeth', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98596', longitude='-43.19001', room_type='Private room', price='235', minimum_nights='2', number_of_reviews='30', last_review='2020-02-25', reviews_per_month='0.25', calculated_host_listings_count='4', availability_365='81', number_of_reviews_ltm=0.0, license=None),
#  Row(id='215887', name='BEAUTIFUL! Spacious,TWIN ROOM.', host_id='1030316', host_name='Elizabeth', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98596', longitude='-43.19001', room_type='Private room', price='414', minimum_nights='2', number_of_reviews='33', last_review='2021-11-16', reviews_per_month='0.27', calculated_host_listings_count='4', availability_365='363', number_of_reviews_ltm=1.0, license=None),
#  Row(id='216436', name='STUNNING WEST RIO BEACHES & MNTNS', host_id='2182548', host_name='Naiana', neighbourhood_group=None, neighbourhood='Vargem Grande', latitude='-22.98271', longitude='-43.49074', room_type='Entire home/apt', price='1429', minimum_nights='1', number_of_reviews='2', last_review='2021-10-17', reviews_per_month='0.02', calculated_host_listings_count='1', availability_365='79', number_of_reviews_ltm=1.0, license=None),
#  Row(id='216461', name='Comfortable room in Flamengo / RIO', host_id='1154263', host_name='Zeilma , Da', neighbourhood_group=None, neighbourhood='Flamengo', latitude='-22.9399', longitude='-43.17676', room_type='Private room', price='851', minimum_nights='1', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='216700', name='Ótimo quarto perto Cristo Redentor', host_id='1118486', host_name='Moara', neighbourhood_group=None, neighbourhood='Laranjeiras', latitude='-22.94373', longitude='-43.19147', room_type='Private room', price='300', minimum_nights='4', number_of_reviews='20', last_review='2020-01-02', reviews_per_month='0.17', calculated_host_listings_count='2', availability_365='359', number_of_reviews_ltm=0.0, license=None),
#  Row(id='219250', name='Varandão Atelier Lounge Sta. Teresa', host_id='1134264', host_name='Ricardo', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.91666', longitude='-43.17947', room_type='Entire home/apt', price='207', minimum_nights='2', number_of_reviews='362', last_review='2021-12-08', reviews_per_month='3.12', calculated_host_listings_count='2', availability_365='327', number_of_reviews_ltm=28.0, license=None),
#  Row(id='220377', name='Hosts in Rio Master room (double)', host_id='1142424', host_name='Taciana', neighbourhood_group=None, neighbourhood='Tijuca', latitude='-22.9288', longitude='-43.24046', room_type='Private room', price='180', minimum_nights='1', number_of_reviews='4', last_review='2017-04-06', reviews_per_month='0.03', calculated_host_listings_count='2', availability_365='341', number_of_reviews_ltm=0.0, license=None),
#  Row(id='220705', name='Comfortable room in quiet street', host_id='1144461', host_name='Rachel', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98246', longitude='-43.19376', room_type='Private room', price='300', minimum_nights='3', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='2', availability_365='278', number_of_reviews_ltm=0.0, license=None),
#  Row(id='223073', name='❤️ MODERN LOFT IN BEST SPOT OF IPANEMA 1 - 120MB❤️', host_id='503995', host_name='❤️ BrUx ❤️', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.9828', longitude='-43.20467', room_type='Entire home/apt', price='472', minimum_nights='1', number_of_reviews='405', last_review='2021-12-12', reviews_per_month='3.25', calculated_host_listings_count='7', availability_365='329', number_of_reviews_ltm=21.0, license=None),
#  Row(id='230989', name='Nice Flat in Copacabana  Ocean View', host_id='1207700', host_name='Maria Luiza', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97923', longitude='-43.18902', room_type='Entire home/apt', price='400', minimum_nights='3', number_of_reviews='113', last_review='2021-12-13', reviews_per_month='0.92', calculated_host_listings_count='4', availability_365='319', number_of_reviews_ltm=11.0, license=None),
#  Row(id='231105', name='Suite 2 people, beach, events, fun', host_id='1208327', host_name='Christian', neighbourhood_group=None, neighbourhood='Jacarepaguá', latitude='-22.969053', longitude='-43.388355', room_type='Entire home/apt', price='209', minimum_nights='3', number_of_reviews='74', last_review='2021-12-05', reviews_per_month='0.74', calculated_host_listings_count='4', availability_365='73', number_of_reviews_ltm=15.0, license=None),
#  Row(id='231497', name='Nice big studio in Copacabana', host_id='1207700', host_name='Maria Luiza', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98238', longitude='-43.19215', room_type='Entire home/apt', price='464', minimum_nights='3', number_of_reviews='59', last_review='2021-11-02', reviews_per_month='0.48', calculated_host_listings_count='4', availability_365='334', number_of_reviews_ltm=7.0, license=None),
#  Row(id='231516', name='Apartment on Copacabana beach', host_id='1207700', host_name='Maria Luiza', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97787', longitude='-43.18792', room_type='Entire home/apt', price='350', minimum_nights='3', number_of_reviews='30', last_review='2016-08-21', reviews_per_month='0.24', calculated_host_listings_count='4', availability_365='299', number_of_reviews_ltm=0.0, license=None),
#  Row(id='236991', name='PRAIA DE COPACABANA!!   1 BLOCK FROM THE BEACH', host_id='1241662', host_name='Nilda', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96488', longitude='-43.17478', room_type='Entire home/apt', price='704', minimum_nights='5', number_of_reviews='35', last_review='2021-12-23', reviews_per_month='0.37', calculated_host_listings_count='2', availability_365='66', number_of_reviews_ltm=15.0, license=None),
#  Row(id='238802', name='EXCELLENT TWO BEDROOM APARTMENT IN COPACABANA', host_id='235496', host_name='Paola & Isak', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96386', longitude='-43.17757', room_type='Entire home/apt', price='1033', minimum_nights='2', number_of_reviews='44', last_review='2021-09-18', reviews_per_month='0.36', calculated_host_listings_count='4', availability_365='315', number_of_reviews_ltm=3.0, license=None),
#  Row(id='239531', name='Bedroom with seaview  surrounded with everything', host_id='792218', host_name='Levy', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96434', longitude='-43.17563', room_type='Entire home/apt', price='438', minimum_nights='2', number_of_reviews='90', last_review='2021-11-30', reviews_per_month='0.74', calculated_host_listings_count='10', availability_365='316', number_of_reviews_ltm=5.0, license=None),
# ...
#  Row(id='1825112', name='Ipa vis 804, 3 bedroom', host_id='9270905', host_name='Carlos', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98326', longitude='-43.2014', room_type='Entire home/apt', price='851', minimum_nights='2', number_of_reviews='5', last_review='2015-02-10', reviews_per_month='0.05', calculated_host_listings_count='26', availability_365='356', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1827758', name='THE PERFECT PLACE IN SANTA TERESA!!', host_id='5228078', host_name='Marcelo', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.92201', longitude='-43.18069', room_type='Entire home/apt', price='514', minimum_nights='2', number_of_reviews='72', last_review='2021-11-28', reviews_per_month='0.72', calculated_host_listings_count='7', availability_365='125', number_of_reviews_ltm=12.0, license=None),
#  Row(id='1827849', name='Large suite in a centennial house', host_id='9269441', host_name='Elmiro', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.9173', longitude='-43.19108', room_type='Private room', price='140', minimum_nights='2', number_of_reviews='24', last_review='2020-02-27', reviews_per_month='0.25', calculated_host_listings_count='4', availability_365='357', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1831772', name='Apt 1 bedroom Copacabana - outdoor pool', host_id='11386725', host_name='Carolina', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96081', longitude='-43.17398', room_type='Entire home/apt', price='563', minimum_nights='4', number_of_reviews='31', last_review='2021-12-01', reviews_per_month='0.32', calculated_host_listings_count='7', availability_365='45', number_of_reviews_ltm=6.0, license=None),
#  Row(id='1834464', name='Ipa Bulhoes 801', host_id='9270905', host_name='Carlos', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98487', longitude='-43.19333', room_type='Entire home/apt', price='227', minimum_nights='1', number_of_reviews='21', last_review='2021-01-05', reviews_per_month='0.21', calculated_host_listings_count='26', availability_365='347', number_of_reviews_ltm=1.0, license=None),
#  Row(id='1835891', name='3 bedrooms in Leblon at 200 mts from the beach !!!', host_id='1982737', host_name='Estadia', neighbourhood_group=None, neighbourhood='Leblon', latitude='-22.98482', longitude='-43.22436', room_type='Entire home/apt', price='3203', minimum_nights='2', number_of_reviews='186', last_review='2021-12-10', reviews_per_month='2.03', calculated_host_listings_count='78', availability_365='257', number_of_reviews_ltm=28.0, license=None),
#  Row(id='1838985', name='Comfortable family apartment', host_id='7694522', host_name='Karl Erik', neighbourhood_group=None, neighbourhood='Gávea', latitude='-22.98253', longitude='-43.23543', room_type='Entire home/apt', price='350', minimum_nights='30', number_of_reviews='15', last_review='2017-06-13', reviews_per_month='0.15', calculated_host_listings_count='2', availability_365='1', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1841457', name='Lovely apt in the best location', host_id='3558427', host_name='Marcia', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97505', longitude='-43.19124', room_type='Entire home/apt', price='1476', minimum_nights='4', number_of_reviews='2', last_review='2014-01-16', reviews_per_month='0.02', calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1841739', name='DESIGN LOFT IN COPACABANA', host_id='7483450', host_name='Karen', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97944', longitude='-43.19047', room_type='Entire home/apt', price='981', minimum_nights='2', number_of_reviews='87', last_review='2021-12-06', reviews_per_month='0.89', calculated_host_listings_count='1', availability_365='176', number_of_reviews_ltm=4.0, license=None),
#  Row(id='1844578', name='Large room in a centennial house', host_id='9269441', host_name='Elmiro', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.91937', longitude='-43.18977', room_type='Private room', price='120', minimum_nights='1', number_of_reviews='11', last_review='2020-01-02', reviews_per_month='0.12', calculated_host_listings_count='4', availability_365='361', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1844920', name='Safe 4 Bedrooms house in Botafogo', host_id='8839490', host_name='Karyn', neighbourhood_group=None, neighbourhood='Botafogo', latitude='-22.95461', longitude='-43.17975', room_type='Entire home/apt', price='1986', minimum_nights='4', number_of_reviews='8', last_review='2020-02-25', reviews_per_month='0.09', calculated_host_listings_count='1', availability_365='349', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1846927', name='Comfort bedroom with two beds', host_id='9647947', host_name='Camilla', neighbourhood_group=None, neighbourhood='Maracanã', latitude='-22.91864', longitude='-43.23409', room_type='Private room', price='170', minimum_nights='2', number_of_reviews='4', last_review='2020-01-29', reviews_per_month='0.04', calculated_host_listings_count='1', availability_365='0', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1847188', name='Cozy and comfortable', host_id='474000', host_name='Marcia', neighbourhood_group=None, neighbourhood='Centro', latitude='-22.91196', longitude='-43.17873', room_type='Entire home/apt', price='224', minimum_nights='1', number_of_reviews='244', last_review='2021-12-19', reviews_per_month='2.93', calculated_host_listings_count='4', availability_365='35', number_of_reviews_ltm=47.0, license=None),
#  Row(id='1849658', name='Copacabana imóvel temporada - property per season', host_id='9659816', host_name='Francisco', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97216', longitude='-43.18922', room_type='Entire home/apt', price='300', minimum_nights='2', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='2', availability_365='350', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1850147', name='Charmoso com Varanda em Copacabana', host_id='7493694', host_name='Regina', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.9812', longitude='-43.19545', room_type='Entire home/apt', price='230', minimum_nights='4', number_of_reviews='19', last_review='2019-03-06', reviews_per_month='0.20', calculated_host_listings_count='1', availability_365='354', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1850325', name='IPANEMA - NICE SUITE WITH BALCONY', host_id='9663614', host_name='Soeli', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98049', longitude='-43.19993', room_type='Private room', price='341', minimum_nights='2', number_of_reviews='49', last_review='2020-02-27', reviews_per_month='0.50', calculated_host_listings_count='1', availability_365='268', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1851472', name='Copa Superhost Família - 2 Qts - Viva o Rio a pé', host_id='1258118', host_name='Vanessa E Emerson', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97772', longitude='-43.19202', room_type='Entire home/apt', price='872', minimum_nights='4', number_of_reviews='182', last_review='2021-11-16', reviews_per_month='1.88', calculated_host_listings_count='1', availability_365='72', number_of_reviews_ltm=19.0, license=None),
#  Row(id='1856688', name='Ipa Dumont 405', host_id='9270905', host_name='Carlos', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98452', longitude='-43.21265', room_type='Entire home/apt', price='482', minimum_nights='3', number_of_reviews='19', last_review='2016-08-14', reviews_per_month='0.21', calculated_host_listings_count='26', availability_365='353', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1856726', name='Suite + terrace Leblon beach block', host_id='9689241', host_name='Georg', neighbourhood_group=None, neighbourhood='Leblon', latitude='-22.98561', longitude='-43.22409', room_type='Entire home/apt', price='760', minimum_nights='3', number_of_reviews='3', last_review='2016-08-14', reviews_per_month='0.04', calculated_host_listings_count='2', availability_365='356', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1858936', name='"Location ""10"" - Sta Teresa/Lapa"', host_id='9699300', host_name='Elisa', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.91601', longitude='-43.18123', room_type='Private room', price='179', minimum_nights='2', number_of_reviews='46', last_review='2020-03-18', reviews_per_month='0.50', calculated_host_listings_count='4', availability_365='357', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1859188', name='3 Quartos na Lapa / julho e feriados', host_id='9700077', host_name='Silvania', neighbourhood_group=None, neighbourhood='Centro', latitude='-22.91367', longitude='-43.18617', room_type='Entire home/apt', price='500', minimum_nights='4', number_of_reviews='1', last_review='2020-02-26', reviews_per_month='0.04', calculated_host_listings_count='1', availability_365='350', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1859583', name='Great location and place !', host_id='9699300', host_name='Elisa', neighbourhood_group=None, neighbourhood='Santa Teresa', latitude='-22.91434', longitude='-43.18126', room_type='Private room', price='331', minimum_nights='2', number_of_reviews='21', last_review='2020-03-01', reviews_per_month='0.21', calculated_host_listings_count='4', availability_365='364', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1860370', name='Mezanino confortável em Copacabana', host_id='4264872', host_name='Maria Das Graças', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97772', longitude='-43.19122', room_type='Private room', price='80', minimum_nights='2', number_of_reviews='72', last_review='2021-09-06', reviews_per_month='0.73', calculated_host_listings_count='5', availability_365='357', number_of_reviews_ltm=5.0, license=None),
#  Row(id='1860840', name='Copa flat one  bedroom with service', host_id='9707402', host_name='Vivian', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97334', longitude='-43.18815', room_type='Entire home/apt', price='477', minimum_nights='3', number_of_reviews='50', last_review='2021-12-06', reviews_per_month='0.51', calculated_host_listings_count='1', availability_365='169', number_of_reviews_ltm=26.0, license=None),
#  Row(id='1860956', name='Cozy little house', host_id='9708044', host_name='Renan', neighbourhood_group=None, neighbourhood='Tauá', latitude='-22.7909', longitude='-43.18547', room_type='Entire home/apt', price='68', minimum_nights='2', number_of_reviews='18', last_review='2020-12-03', reviews_per_month='0.56', calculated_host_listings_count='1', availability_365='301', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1865009', name='Studio at Rio de Janeiro - Downtown', host_id='9718043', host_name='Luiz', neighbourhood_group=None, neighbourhood='Glória', latitude='-22.91948', longitude='-43.17627', room_type='Entire home/apt', price='278', minimum_nights='5', number_of_reviews='3', last_review='2016-08-19', reviews_per_month='0.03', calculated_host_listings_count='3', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1865173', name='Sea view Penthouse in Copacabana', host_id='8855599', host_name='Geneviève', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98367', longitude='-43.1918', room_type='Entire home/apt', price='1928', minimum_nights='4', number_of_reviews='2', last_review='2015-02-18', reviews_per_month='0.02', calculated_host_listings_count='1', availability_365='363', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1867075', name='Penthouse on the Beach - In Brazil', host_id='9733946', host_name='Paulo', neighbourhood_group=None, neighbourhood='Barra da Tijuca', latitude='-22.97366', longitude='-43.39285', room_type='Entire home/apt', price='1500', minimum_nights='10', number_of_reviews='5', last_review='2020-11-26', reviews_per_month='0.05', calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1867414', name='EXCELENTE APTº COPACABANA -TEMPORADA CURTA E LONGA', host_id='9725950', host_name='Maria Eliza', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96899', longitude='-43.18804', room_type='Entire home/apt', price='371', minimum_nights='4', number_of_reviews='23', last_review='2021-12-08', reviews_per_month='0.24', calculated_host_listings_count='4', availability_365='81', number_of_reviews_ltm=8.0, license=None),
#  Row(id='1868822', name='Quarto (bedroom+bathr) no Itanhangá', host_id='9741427', host_name='Thiago', neighbourhood_group=None, neighbourhood='Itanhangá', latitude='-22.98521', longitude='-43.32922', room_type='Private room', price='681', minimum_nights='2', number_of_reviews='0', last_review=None, reviews_per_month=None, calculated_host_listings_count='1', availability_365='365', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1873520', name='DUPLEX PENTHOUSE 2 SUITES  IPANEMA', host_id='532498', host_name='Luis', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98604', longitude='-43.20693', room_type='Entire home/apt', price='1200', minimum_nights='2', number_of_reviews='1', last_review='2014-04-22', reviews_per_month='0.01', calculated_host_listings_count='47', availability_365='354', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1877686', name='Between Copacabana and Ipanema', host_id='9779062', host_name='Jacqueline', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98331', longitude='-43.19137', room_type='Entire home/apt', price='1000', minimum_nights='3', number_of_reviews='9', last_review='2021-11-16', reviews_per_month='0.09', calculated_host_listings_count='1', availability_365='347', number_of_reviews_ltm=1.0, license=None),
#  Row(id='1879131', name='A cozy apartment in Rio', host_id='9784682', host_name='Thais', neighbourhood_group=None, neighbourhood='Centro', latitude='-22.91666', longitude='-43.18825', room_type='Entire home/apt', price='357', minimum_nights='5', number_of_reviews='15', last_review='2016-08-20', reviews_per_month='0.15', calculated_host_listings_count='1', availability_365='268', number_of_reviews_ltm=0.0, license=None),
#  Row(id='1879333', name='Ipa Prudente 1108', host_id='9270905', host_name='Carlos', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98668', longitude='-43.20034', room_type='Entire home/apt', price='284', minimum_nights='1', number_of_reviews='36', last_review='2021-10-12', reviews_per_month='0.38', calculated_host_listings_count='26', availability_365='344', number_of_reviews_ltm=11.0, license=None),
#  Row(id='1880407', name='LUXURY FLAT AT IPANEMA 2 SUITES', host_id='532498', host_name='Luis', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98518', longitude='-43.20673', room_type='Entire home/apt', price='500', minimum_nights='2', number_of_reviews='3', last_review='2021-01-30', reviews_per_month='0.04', calculated_host_listings_count='47', availability_365='308', number_of_reviews_ltm=1.0, license=None),
#  Row(id='1885051', name='Room for Couple in Rio de Janeiro', host_id='9808109', host_name='Osni', neighbourhood_group=None, neighbourhood='Curicica', latitude='-22.95243', longitude='-43.38468', room_type='Private room', price='227', minimum_nights='3', number_of_reviews='1', last_review='2016-08-16', reviews_per_month='0.02', calculated_host_listings_count='1', availability_365='364', number_of_reviews_ltm=0.0, license=None),
#  ...]

# %% [markdown]
# Para evitar lançar uma exceção de falta de memória, use `DataFrame.take()`.

# %%
df_spark.take(5)
# Out:
# [Row(id='17878', name='Very Nice 2Br in Copacabana w. balcony, fast WiFi', host_id='68997', host_name='Matthias', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.96599', longitude='-43.1794', room_type='Entire home/apt', price='350', minimum_nights='5', number_of_reviews='267', last_review='2021-12-03', reviews_per_month='1.92', calculated_host_listings_count='1', availability_365='257', number_of_reviews_ltm=10.0, license=None),
#  Row(id='24480', name='Nice and cozy near Ipanema Beach, w/ home office', host_id='99249', host_name='Goya', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98405', longitude='-43.20189', room_type='Entire home/apt', price='296', minimum_nights='3', number_of_reviews='85', last_review='2018-02-14', reviews_per_month='0.62', calculated_host_listings_count='1', availability_365='107', number_of_reviews_ltm=0.0, license=None),
#  Row(id='25026', name='Beautiful Modern Decorated Studio in Copa', host_id='102840', host_name='Viviane', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.97735', longitude='-43.19105', room_type='Entire home/apt', price='387', minimum_nights='3', number_of_reviews='238', last_review='2020-02-15', reviews_per_month='1.69', calculated_host_listings_count='1', availability_365='206', number_of_reviews_ltm=0.0, license=None),
#  Row(id='35636', name='Cosy flat close to Ipanema beach', host_id='153232', host_name='Patricia', neighbourhood_group=None, neighbourhood='Ipanema', latitude='-22.98839', longitude='-43.19232', room_type='Entire home/apt', price='172', minimum_nights='2', number_of_reviews='181', last_review='2020-03-15', reviews_per_month='1.82', calculated_host_listings_count='1', availability_365='207', number_of_reviews_ltm=0.0, license=None),
#  Row(id='35764', name='COPACABANA SEA BREEZE  -  RIO - 20 X Superhost', host_id='153691', host_name='Patricia Miranda & Paulo', neighbourhood_group=None, neighbourhood='Copacabana', latitude='-22.98107', longitude='-43.19136', room_type='Entire home/apt', price='260', minimum_nights='3', number_of_reviews='378', last_review='2021-12-05', reviews_per_month='2.76', calculated_host_listings_count='1', availability_365='58', number_of_reviews_ltm=32.0, license=None)]

# %% [markdown]
# O PySpark DataFrame também fornece a conversão de volta para um DataFrame pandas para aproveitar a API do pandas. Observe que o toPandas também coleta todos os dados no lado do driver que podem facilmente causar um erro de falta de memória quando os dados são muito grandes para caber no lado do driver.

# %%
df_spark.toPandas()
# Out:
#              id                                               name    host_id  \
# 0         17878  Very Nice 2Br in Copacabana w. balcony, fast WiFi      68997
# 1         24480   Nice and cozy near Ipanema Beach, w/ home office      99249
# 2         25026          Beautiful Modern Decorated Studio in Copa     102840
# 3         35636                   Cosy flat close to Ipanema beach     153232
# 4         35764     COPACABANA SEA BREEZE  -  RIO - 20 X Superhost     153691
# ...         ...                                                ...        ...
# 24708  53957052                             COPACABANA FAMILY HOME  190156483
# 24709  53957980    Stunning & Luxurious Apartment in Flamengo (#2)   20561832
# 24710  53958210                   Apartamento aconchegante no Leme   71566676
# 24711  53958814  Apto 520 na Quadra da Praia de Copacabana Posto 3   33865879
# 24712  53967814    Villa overlooking Pedra da Gávea in São Conrado    1982737
#
#                       host_name neighbourhood_group neighbourhood  \
# 0                      Matthias                None    Copacabana
# 1                          Goya                None       Ipanema
# 2                       Viviane                None    Copacabana
# 3                      Patricia                None       Ipanema
# 4      Patricia Miranda & Paulo                None    Copacabana
# ...                         ...                 ...           ...
# 24708                  Fernando                None    Copacabana
# 24709                     Pedro                None      Flamengo
# 24710              Dulce/Raquel                None          Leme
# 24711                    Miguel                None    Copacabana
# 24712                   Estadia                None   São Conrado
#
#                   latitude            longitude        room_type price  \
# 0                -22.96599             -43.1794  Entire home/apt   350
# 1                -22.98405            -43.20189  Entire home/apt   296
# 2                -22.97735            -43.19105  Entire home/apt   387
# 3                -22.98839            -43.19232  Entire home/apt   172
# 4                -22.98107            -43.19136  Entire home/apt   260
# ...                    ...                  ...              ...   ...
# 24708           -22.977974           -43.190044  Entire home/apt  1786
# 24709           -22.932098            -43.17709  Entire home/apt   460
# 24710  -22.962902258070564  -43.170973085960014  Entire home/apt   891
# 24711   -22.96871398426808   -43.18329311240373  Entire home/apt   177
# 24712  -22.994538534890495  -43.258093286956715  Entire home/apt   818
#
#       minimum_nights number_of_reviews last_review reviews_per_month  \
# 0                  5               267  2021-12-03              1.92
# 1                  3                85  2018-02-14              0.62
# 2                  3               238  2020-02-15              1.69
# 3                  2               181  2020-03-15              1.82
# 4                  3               378  2021-12-05              2.76
# ...              ...               ...         ...               ...
# 24708              4                 0        None              None
# 24709              2                 1  2021-12-24                 1
# 24710              2                 0        None              None
# 24711              4                 0        None              None
# 24712              1                 0        None              None
#
#       calculated_host_listings_count availability_365  number_of_reviews_ltm  \
# 0                                  1              257                   10.0
# 1                                  1              107                    0.0
# 2                                  1              206                    0.0
# 3                                  1              207                    0.0
# 4                                  1               58                   32.0
# ...                              ...              ...                    ...
# 24708                              1              365                    0.0
# 24709                              4                3                    1.0
# 24710                              1              267                    0.0
# 24711                              4               81                    0.0
# 24712                             78              304                    0.0
#
#        license
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 24708      NaN
# 24709      NaN
# 24710      NaN
# 24711      NaN
# 24712      NaN
#
# [24713 rows x 18 columns]

# %% [markdown]
# Também podemos utilizar agrupamentos para alguns cálculos:

# %%
# spark_df.groupby(group_column).action(column_to_transform).show()
df_spark.groupby('neighbourhood').avg('number_of_reviews_ltm').show()
# Out:
# +-------------------+--------------------------+
# |      neighbourhood|avg(number_of_reviews_ltm)|
# +-------------------+--------------------------+
# |             Cocotá|                       0.0|
# |              Gávea|         1.053191489361702|
# |           -22.9851|                      null|
# |       Tomás Coelho|        0.3333333333333333|
# |  -23.0633674927355|                      null|
# |            Ipanema|         4.502656313853699|
# |          -22.98487|                      null|
# |           -22.8927|                      null|
# |          -22.97122|                      null|
# |           Realengo|        0.4444444444444444|
# |          -22.99748|                      null|
# |      Gardênia Azul|        0.4230769230769231|
# |          -22.98135|                      null|
# |              Rocha|                     0.125|
# |      Bento Ribeiro|                     3.625|
# |Vicente de Carvalho|                       3.0|
# | -22.97010221488871|                      null|
# |          -22.99694|                      null|
# |          -23.00357|                      null|
# |          -22.98148|                      null|
# +-------------------+--------------------------+
# only showing top 20 rows

# %%
df_spark.dtypes
# Out:
# [('id', 'string'),
#  ('name', 'string'),
#  ('host_id', 'string'),
#  ('host_name', 'string'),
#  ('neighbourhood_group', 'string'),
#  ('neighbourhood', 'string'),
#  ('latitude', 'string'),
#  ('longitude', 'string'),
#  ('room_type', 'string'),
#  ('price', 'string'),
#  ('minimum_nights', 'string'),
#  ('number_of_reviews', 'string'),
#  ('last_review', 'string'),
#  ('reviews_per_month', 'string'),
#  ('calculated_host_listings_count', 'string'),
#  ('availability_365', 'string'),
#  ('number_of_reviews_ltm', 'double'),
#  ('license', 'int')]

# %% [markdown]
# Veja que algumas variáveis numéricas estão aparecendo como string. Podemos, também, mudar o tipo dessas colunas com a sintaxe a seguir:
#
# [withColumn Documentation](https://sparkbyexamples.com/spark/spark-dataframe-withcolumn/#:~:text=Spark%20withColumn()%20is%20a,column%20operations%20with%20Scala%20examples.)

# %%
df_spark = df_spark.withColumn("price", df_spark["price"].cast("double"))

# %%
df_spark.dtypes
# Out:
# [('id', 'string'),
#  ('name', 'string'),
#  ('host_id', 'string'),
#  ('host_name', 'string'),
#  ('neighbourhood_group', 'string'),
#  ('neighbourhood', 'string'),
#  ('latitude', 'string'),
#  ('longitude', 'string'),
#  ('room_type', 'string'),
#  ('price', 'double'),
#  ('minimum_nights', 'string'),
#  ('number_of_reviews', 'string'),
#  ('last_review', 'string'),
#  ('reviews_per_month', 'string'),
#  ('calculated_host_listings_count', 'string'),
#  ('availability_365', 'string'),
#  ('number_of_reviews_ltm', 'double'),
#  ('license', 'int')]

# %%
df_spark.groupby('neighbourhood').avg('price').show()
# Out:
# +-------------------+------------------+
# |      neighbourhood|        avg(price)|
# +-------------------+------------------+
# |             Cocotá|             150.0|
# |              Gávea|1140.2659574468084|
# |           -22.9851|               3.0|
# |       Tomás Coelho|             105.0|
# |  -23.0633674927355|               1.0|
# |            Ipanema|1335.4372701266857|
# |          -22.98487|               3.0|
# |           -22.8927|               2.0|
# |          -22.97122|               1.0|
# |           Realengo| 633.2222222222222|
# |          -22.99748|               3.0|
# |      Gardênia Azul| 526.4230769230769|
# |          -22.98135|               1.0|
# |              Rocha|           211.375|
# |      Bento Ribeiro|           316.625|
# |Vicente de Carvalho|              80.0|
# | -22.97010221488871|               1.0|
# |          -22.99694|               4.0|
# |          -23.00357|               2.0|
# |          -22.98148|               3.0|
# +-------------------+------------------+
# only showing top 20 rows
